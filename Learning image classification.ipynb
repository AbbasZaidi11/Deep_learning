# %%
import tensorflow as tf
import numpy as np

# %% [markdown]
# <h1>First method to load an image</h1>

# %%
filename=r"C:/Users/Abbas/Downloads/download.jpg"

# %%
from IPython.display import Image
Image(filename='C:/Users/Abbas/Downloads/download.jpg',width=224,height=224)
# The reason we chose 224 * 224 image size is because most of the deep learning models work on this size

# %% [markdown]
# <h1>Second method to load an image</h1>

# %%
from tensorflow.keras.preprocessing import image
img=image.load_img(filename,target_size=(224,224))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %% [markdown]
# <h1>Third method to load an image</h1>

# %%
import cv2

# %%
imgg=cv2.imread(filename)

# %%
plt.imshow(imgg)

# %%
imgg=cv2.resize(imgg,(224,224))

# %%
plt.imshow(imgg)

# %%
plt.imshow(cv2.cvtColor(imgg,cv2.COLOR_BGR2RGB))

# %% [markdown]
# <h1>Fourth method to load an image</h1>

# %%
from PIL import Image

# %%
im = Image.open(filename)

# %%
im=im.resize((224,224))

# %%
plt.imshow(im)

# %% [markdown]
# <h1>Lets load the deep learning model</h1>

# %%
mobile = tf.keras.applications.mobilenet.MobileNet()
# mobile here is the variable name
## deep learning model weights - pre-trained
# mobile net is the deep learning architecture for image classification

# %%
#Creating a model
#Training a model
#test or validate
#Predict

# %%
mobile = tf.keras.applications.mobilenet_v2.MobileNetV2()

# %%
anyone = tf.keras.applications.mobilenet_v3

# %% [markdown]
# # Pre-processing of the image

# %%
from tensorflow.keras.preprocessing import image
img=image.load_img(filename,target_size=(224,224))

# %%
resized_img=image.img_to_array(img)
final_image = np.expand_dims(resized_img,axis=0) 
#need fourth dimension
#we are expanding the dimensions
final_image = tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
predictions=mobile.predict(final_image)
# Out:
# 1/1 [==============================] - 0s 43ms/step

# %%
from tensorflow.keras.applications import imagenet_utils

# %%
results=imagenet_utils.decode_predictions(predictions) ##here we are decoding the predictions

# %%
print(results)
# Out:
# [[('n02099712', 'Labrador_retriever', 0.39417902), ('n02104029', 'kuvasz', 0.2379044), ('n02099601', 'golden_retriever', 0.18117619), ('n02111500', 'Great_Pyrenees', 0.09812977), ('n04409515', 'tennis_ball', 0.035250053)]]

# %% [markdown]
# # Predicting for the second time using Mobilenet V2

# %%
predictions=mobile.predict(final_image)
# Out:
# 1/1 [==============================] - 1s 739ms/step

# %%
results=imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n02099712', 'Labrador_retriever', 0.26973772), ('n02104029', 'kuvasz', 0.23081572), ('n02111500', 'Great_Pyrenees', 0.08065501), ('n02099601', 'golden_retriever', 0.047274034), ('n02095889', 'Sealyham_terrier', 0.009945268)]]

# %%
predictions=mobile.predict(final_image)
# Out:
# 1/1 [==============================] - 0s 76ms/step

# %%
results=imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n02099712', 'Labrador_retriever', 0.26973772), ('n02104029', 'kuvasz', 0.23081572), ('n02111500', 'Great_Pyrenees', 0.08065501), ('n02099601', 'golden_retriever', 0.047274034), ('n02095889', 'Sealyham_terrier', 0.009945268)]]
